# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
print(iris.shape)
# Out:
# (150, 5)

# %%
sns.boxplot(data = iris , palette = "pastel")
plt.title("Boxplot of Iris dataset")
plt.show()

# %%
sepal_data = iris['sepal_width']
sns.boxplot(data = sepal_data , palette = "pastel")
plt.title("Sepal Width of Iris dataset")
plt.show()
# Out:
# <ipython-input-57-873629134b93>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = sepal_data , palette = "pastel")

# %%
sq1 = sepal_data.quantile(0.25)
sq3 = sepal_data.quantile(0.75)
print("Quantile 25%",sq1)
print("Quantile 75%",sq3)
sepal_iqr = sq3 - sq1
sepal_lower_bound = sq1 - (1.5 * sepal_iqr)
sepal_upper_bound = sq3 + (1.5 * sepal_iqr)
print("Lower Bound",sepal_lower_bound)
print("Upper Bound",sepal_upper_bound)
filtered_sepal_data = sepal_data[(sepal_data >= sepal_lower_bound) & (sepal_data <= sepal_upper_bound)]
filtered_sepal_data
# Out:
# Quantile 25% 2.8
# Quantile 75% 3.3
# Lower Bound 2.05
# Upper Bound 4.05
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 146, dtype: float64

# %%
sns.boxplot(data=filtered_sepal_data, palette="pastel")
plt.title("Sepal Width of Iris dataset")
plt.show()
# Out:
# <ipython-input-59-9e4a65041336>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=filtered_sepal_data, palette="pastel")

# %%
iris["sepal_width"] = filtered_sepal_data
sns.boxplot(data = iris["sepal_width"] , palette = "pastel")
plt.title("Sepal Width of Iris dataset")
plt.show()
# Out:
# <ipython-input-64-8a7754c1603c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = iris["sepal_width"] , palette = "pastel")

# %%
sns.boxplot(data = iris , palette = "pastel")
plt.title("Boxplot of Iris dataset")
plt.show()

# %%
print(iris.head())
iris
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# ...

# %%
iris.hist(figsize=(10, 6), bins=20)
plt.suptitle("Distribution of Features", fontsize=16)
plt.show()

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   146.000000    150.000000   150.000000
# mean       5.843333     3.040411      3.758000     1.199333
# std        0.828066     0.397853      1.765298     0.762238
# min        4.300000     2.200000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.000000      6.900000     2.500000

# %%
print(iris.isnull().sum())
iris = iris.dropna()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  146 non-null    float64
#  1   sepal_width   146 non-null    float64
#  2   petal_length  146 non-null    float64
#  3   petal_width   146 non-null    float64
#  4   species       146 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.8+ KB
